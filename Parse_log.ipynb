# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load JSON file

# %%
with open('/home/fbach/Downloads/prontos_pretty.json') as data_file:    
    json_data = json.load(data_file)

# %% [markdown]
# LOG JSON Data Keys

# %%
print(json_data[0].keys())
# Out:
# [u'hwSerial', u'informationRequest', u'topImportance', u'repeatability', u'compManufacturer', u'customised', u'hwUnit', u'rdInfo', u'deliveryPackage', u'reportedDate', u'faultAnalysis', u'othersInterested', u'id', u'lastMod', u'rdPriority', u'severity', u'title', u'reportedBy', u'groupIncharge', u'commentAttachment', u'feature', u'problemType', u'problemReportIds', u'groupName', u'state', u'compPackage', u'statusLog', u'discoveredIn', u'customizationFields', u'hwVersion', u'correction', u'attachment', u'product', u'securityFault', u'description', u'testSubphase', u'revisionHistory', u'reasonTransferLst', u'optional', u'additional', u'viewDefaults', u'genericFault', u'devFaultCoord', u'compCode', u'author', u'softwareBuild', u'featureComment', u'softwareRelease']

# %%
print([json_data[idx]['othersInterested'] for idx in range(0, len(json_data))])
# Out:
# [[], [], [u'Sutinen, Jukka (Nokia - FI/Oulu)'], [], [], [], [], [], [u'Bak, Tomasz 1. (Nokia - PL/Wroclaw)'], [], [], [], [], [], [u'Hsiao, George (Nokia - US/Irving)'], [u'Mendoza, John (Nokia - PH/Quezon City)', u'Soikko, Natalia (Nokia - FI/Oulu)', u'Kyllonen, Mirka (Nokia - FI/Oulu)'], [], [], [], [], [], [], [], [], [], [u'Milulescu, Maria (Nokia - RO)'], [], [], [u'Samson, Randy (Nokia - US/Irving)'], [], [], [], [], [], [], [], [], [], [], [u'Liu, Xiaojing (Nokia - CN/Hangzhou)', u'Wang, Kevin K. (Nokia - CN/Hangzhou)', u'Wang, Ting 5. (Nokia - CN/Hangzhou)', u'Liu, Jay (Nokia - CN/Hangzhou)'], [], [u'Sutinen, Jukka (Nokia - FI/Oulu)'], [], [], [], [], [u'Vu, Tung X. (Nokia - FI/Oulu)', u'Ollanketo, Mikko (Nokia - FI/Oulu)', u'Vehniainen, Jukka (Nokia - FI/Oulu)', u'Parfitt, Kirk (Nokia - US/Irving)'], [u'Waidmann, Stephan (Nokia - DE/Ulm)', u'Fischer, Markus (Nokia - DE/Ulm)', u'Qureshi, Muhammad A. (Nokia - DE/Ulm)', u'Pennanen, Virpi (Nokia - FI/Oulu)', u'Filipiec, Roman (N
# ...
